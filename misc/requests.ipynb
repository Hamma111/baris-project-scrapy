# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import openpyxl

url= "https://www.hepsiburada.com/magaza/first-sourcer?sayfa=1"
headers_param = {"user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36"}

r = requests.get(url,headers=headers_param)
soup=BeautifulSoup(r.content,"lxml")

liste = []

st3 = soup.find_all ("li",attrs={"data-index":"1"})
for detaylar in st3:
    link_basi = "https://www.hepsiburada.com"
    link_sonu = detaylar.a.get("href")
    link =  link_basi + link_sonu
    print(link)
    r1 = requests.get(link, headers=headers_param)
    soup1 = BeautifulSoup(r1.content,"lxml")

    indirimli_ucret=soup1.find("span",{"itemprop":"price"}).text.strip().replace("TL","")
    print(indirimli_ucret)
    brandname = soup1.find("span",attrs={"class": "brand-name"}).getText('', True)
    print(brandname)
    name = soup1.find("h1",attrs={"itemprop":"name"}).getText('',True)
    print(name)
    #rating=soup1.find("span",attrs={"class":"rating-star"}).text.strip()
    #print(rating)
    #degerlendirme=soup1.find("div",attrs={"id":"comments-container"}).text.strip().replace("\n","")
    #print(degerlendirme)
    urun_photo = soup1.img.get("src")
    print(urun_photo)

    resimler=soup1.find("img",attrs={"class":"product-image", "src":True}).get("src")
    print(resimler)

    print()

    liste.append([link,brandname,name,urun_photo,indirimli_ucret])
    df = pd.DataFrame(liste)
    df.columns=["Urun_Linki","Marka","Urun_Adi","Urun_Photo","Fiyat"]
    df.to_excel("firstsourcer.xlsx")
# Out:
# https://www.hepsiburada.com/mark-ryden-laptop-notebook-sirt-cantasi-9116-siyah-usb-sarj-portlu-p-HBV00001493UJ?magaza=First%20Sourcer
# 399,40
#
# Mark Ryden
# Mark Ryden Laptop - Notebook Sırt Çantası 9116 Siyah (Usb Sarj Portlu)
# https://productimages.hepsiburada.net/s/50/550/11032549359666.jpg
# https://productimages.hepsiburada.net/s/50/550/11032549359666.jpg
#
# https://www.hepsiburada.com/xiaomi-mitu-isikli-ayarlanabilir-3-tekerlekli-scooter-mavi-p-HBV00000UO6XX?magaza=First%20Sourcer
# 417,00
#
# Xiaomi
# Xiaomi Mitu Işıklı Ayarlanabilir 3 Tekerlekli Scooter Mavi
# https://productimages.hepsiburada.net/s/40/550/10652044492850.jpg
# https://productimages.hepsiburada.net/s/40/550/10652044492850.jpg
#
# https://www.hepsiburada.com/xiaomi-huohou-otomatik-sarap-sisesi-kiti-elektrikli-tirbuson-p-HBV00000KFB5N?magaza=First%20Sourcer
# 170,00
#
# Xiaomi
# Xiaomi Huohou Otomatik Şarap Şişesi Kiti Elektrikli Tirbuşon
# https://productimages.hepsiburada.net/s/28/550/10216068644914.jpg
# https://productimages.hepsiburada.net/s/28/550/10216068644914.jpg
#
# https://www.hepsiburada.com/xiaomi-masa-uzeri-akilli-led-lamba-p-HBV000005XPOH?magaza=First%20Sourcer
# 320,40
#
# Xiaomi
# Xiaomi Masa Üzeri Akıllı LED Lamba
# https://productimages.hepsiburada.net/s/4/550/9651109134386.jpg
# https://productimages.hepsiburada.net/s/4/550/9651109134386.jpg
#
# https://www.hepsiburada.com/bullcaptain-deri-evrak-ve-laptop-cantasi-kahverengi-gwb-044-p-HBV00000Y6OOJ?magaza=First%20Sourcer
# 375,00
#
# Bullcaptain
# Bullcaptain Deri Evrak ve Laptop Çantası (Kahverengi Gwb 044)
# https://productimages.hepsiburada.net/l/44/600-800/10798690893874.jpg
# https://productimages.hepsiburada.net/l/44/600-800/10798690893874.jpg
#
# https://www.hepsiburada.com/dr-pen-m8-w-dermapen-cihazi-yurt-disindan-p-HBV00001496LX?magaza=First%20Sourcer
# 599,82
#
# Dr. Pen
# Dr. Pen M8-W Dermapen Cihazı (Yurt Dışından)
