# %%
import requests
import os
import pandas as pd
from bs4 import BeautifulSoup
import json
from time import sleep
from tqdm.auto import tqdm
from datetime import datetime

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36 Edg/89.0.774.63',
          }

# %%
site = requests.get('https://www.timeanddate.com/holidays/?allcountries',
                   headers=headers,)

# %%
soup = BeautifulSoup(site.content)

# %%
# countries_urls = ["https://www.timeanddate.com"+x.find('a')['href'] for x in soup.find("article", {'class':'category-list'}).findAll('li')]
countries_urls = ["https://www.timeanddate.com/holidays/philippines/"]

# %%
years = ["2018","2019", "2020", "2021", "2022"]

# %%
all_dfs = []

# %%
for country_url in tqdm(countries_urls[:]):
    print(country_url, end=" => ")
    for year in years:
        web_url = country_url + year
        try:
            df = pd.read_html(web_url)[0]#.dropna()
        except ValueError:
            continue
        if len(df.columns) == 4:
            df['Details'] = ""
#         df['Details'] = ""
        df = df.dropna()
        df.columns = ["Date", "Day", "Name", "Type" , "Details"]
        df['Country'] = country_url.split("/")[-2].capitalize()
        df['Year'] = year
        print(df.shape[0], end=", ")
#         df.columns = ['Date', 'Day', 'Name', 'Type', 'Country', 'Year']
        all_dfs.append(df)
        del df
    print()
        
#         break
#     break
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# https://www.timeanddate.com/holidays/philippines/ => 34, 37, 37, 33, 33,

# %%
df = pd.concat(all_dfs)

# %%
df
# Out:
#          Date        Day                                               Name  \
# 0  2018-01-01     Monday                                     New Year's Day
# 2  2018-02-16     Friday                       Chinese Lunar New Year's Day
# 3  2018-02-25     Sunday                           People Power Anniversary
# 5  2018-03-21  Wednesday                                      March Equinox
# 6  2018-03-29   Thursday                                    Maundy Thursday
# 7  2018-03-30     Friday                                        Good Friday
# 8  2018-03-31   Saturday                                     Black Saturday
# 9  2018-03-31   Saturday                                     Black Saturday
# 11 2018-04-01     Sunday                                      Easter Sunday
# 12 2018-04-09     Monday                                   The Day of Valor
# 13 2018-04-13     Friday                           Lailatul Isra Wal Mi Raj
# 15 2018-05-01    Tuesday                                          Labor Day
# 16 2018-05-14     Monday                            Special Non-Working Day
# 18 2018-06-12    Tuesday                                   Independence Day
# 19 2018-06-15     Friday                                        Eidul-Fitar
# 20 2018-06-21   Thursday                                      June Solstice
# 23 2018-08-21    Tuesday               Eid al-Adha (Feast of the Sacrifice)
# 24 2018-08-21    Tuesday                                   Ninoy Aquino Day
# 25 2018-08-22  Wednesday                                  Eid al-Adha Day 2
# 26 2018-08-27     Monday                                National Heroes Day
# 28 2018-09-12  Wednesday                                         Amun Jadid
# 29 2018-09-23     Sunday                                  September Equinox
# 32 2018-11-01   Thursday                                    All Saints' Day
# 33 2018-11-02     Friday                                     All Souls' Day
# 34 2018-11-02     Friday                 Additional Special Non-Working Day
# 35 2018-11-21  Wednesday                                     Maulid un-Nabi
# 36 2018-11-30     Friday                                      Bonifacio Day
# 38 2018-12-08   Saturday                 Feast of the Immaculate Conception
# 39 2018-12-22   Saturday                                  December Solstice
# 40 2018-12-24     Monday                                      Christmas Eve
# ..        ...        ...                                                ...
# 4  2022-02-25     Friday                           People Power Anniversary
# 6  2022-03-01    Tuesday                           Lailatul Isra Wal Mi Raj
# 40     Special Non-working Holiday          Philippines  2018  24 Dec
# ..                             ...     ...          ...   ...     ...
# 4      Special Non-working Holiday          Philippines  2022  25 Feb
# 6             Common local holiday          Philippines  2022   1 Mar
# 7                           Season          Philippines  2022  20 Mar
# 9                  Regular Holiday          Philippines  2022   9 Apr
# 10                 Regular Holiday          Philippines  2022  14 Apr
# 11                 Regular Holiday          Philippines  2022  15 Apr
# 12     Special Non-working Holiday          Philippines  2022  16 Apr
# 13                      Observance          Philippines  2022  17 Apr
# 15                 Regular Holiday          Philippines  2022   1 May
# 16                 Regular Holiday          Philippines  2022   3 May
# 18                 Regular Holiday          Philippines  2022  12 Jun
# 19                          Season          Philippines  2022  21 Jun
# 21                 Regular Holiday          Philippines  2022  10 Jul
# 22            Common local holiday          Philippines  2022  11 Jul
# 23    Muslim, Common local holiday          Philippines  2022  30 Jul
# 25     Special Non-working Holiday          Philippines  2022  21 Aug
# 26                 Regular Holiday          Philippines  2022  29 Aug
# 28  Special Working Public Holiday          Philippines  2022   3 Sep
# 29  Special Working Public Holiday          Philippines  2022   8 Sep
# 30                          Season          Philippines  2022  23 Sep
# 32            Common local holiday          Philippines  2022   8 Oct
# 34     Special Non-working Holiday          Philippines  2022   1 Nov
# 35                      Observance          Philippines  2022   2 Nov
# 36                 Regular Holiday          Philippines  2022  30 Nov
# 38     Special Non-working Holiday          Philippines  2022   8 Dec
# 39                          Season          Philippines  2022  22 Dec
# 40                      Observance          Philippines  2022  24 Dec
# 41                 Regular Holiday          Philippines  2022  25 Dec
# 42                 Regular Holiday          Philippines  2022  30 Dec
# 43     Special Non-working Holiday          Philippines  2022  31 Dec
#
# [174 rows x 8 columns]

# %%
df.reset_index().drop(['index'], axis=1).to_excel('Holidays Data.xlsx', index=False)

# %%
df['Date_'] = df['Date']

# %%
df['Date'] = df['Date_'] + " " + df['Year']

# %%
df.Date =  df.Date.apply(lambda x: datetime.strptime(x, '%d %b %Y'))

# %%
df.to_excel('temp.xlsx', index=False)

# %%
import requests
import os
import pandas as pd
from bs4 import BeautifulSoup
import json
from time import sleep
from tqdm.auto import tqdm

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36 Edg/89.0.774.63',}
site = requests.get('https://www.timeanddate.com/holidays/?allcountries', headers=headers,)
soup = BeautifulSoup(site.content)

# urls of all the countries
countries_urls = ["https://www.timeanddate.com"+x.find('a')['href'] for x in soup.find("article", {'class':'category-list'}).findAll('li')]

# the years we want to extract. you can change this and use the years you want.
years = ["2018","2019", "2020", "2021", "2022"]

all_dfs = []
for country_url in tqdm(countries_urls): # country loop
    print(country_url, end=" => ") 
    for year in years: # year loop
        
        web_url = country_url + year
        try:
            df = pd.read_html(web_url)[0].dropna()
        except ValueError: # in case there is not tables in the website
            continue
        if len(df.columns) == 4:
            df['Details'] = ""
        df.columns = ["Date", "Day", "Name", "Type" , "Details"]
        df['Country'] = country_url.split("/")[-2].capitalize()
        df['Year'] = year
        all_dfs.append(df)
        
        print(df.shape[0], end=", ")
        del df 
    print()
        
#         break
#     break


df = pd.concat(all_dfs)
df.reset_index().drop(['index'], axis=1).to_excel('Holidays Data.xlsx', index=False)
