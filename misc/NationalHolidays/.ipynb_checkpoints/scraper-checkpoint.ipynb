# %%
import requests
import os
import pandas as pd
from bs4 import BeautifulSoup
import json
from time import sleep
from tqdm.auto import tqdm

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36 Edg/89.0.774.63',
          }

# %%
site = requests.get('https://www.timeanddate.com/holidays/?allcountries',
                   headers=headers,)

# %%
soup = BeautifulSoup(site.content)

# %%
# countries_urls = ["https://www.timeanddate.com"+x.find('a')['href'] for x in soup.find("article", {'class':'category-list'}).findAll('li')]
countries_urls = ["https://www.timeanddate.com/holidays/philippines/"]

# %%
years = ["2018","2019", "2020", "2021", "2022"]

# %%
all_dfs = []

# %%
for country_url in tqdm(countries_urls[:]):
    print(country_url, end=" => ")
    for year in years:
        web_url = country_url + year
        try:
            df = pd.read_html(web_url)[0]#.dropna()
        except ValueError:
            continue
        if len(df.columns) == 4:
            df['Details'] = ""
        df['Details'] = ""
        df.columns = ["Date", "Day", "Name", "Type" , "Details"]
        df['Country'] = country_url.split("/")[-2].capitalize()
        df['Year'] = year
        print(df.shape[0], end=", ")
#         df.columns = ['Date', 'Day', 'Name', 'Type', 'Country', 'Year']
        all_dfs.append(df)
        del df
    print()
        
#         break
#     break
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# https://www.timeanddate.com/holidays/philippines/ => 45, 48, 48, 44,

# %%
pd.read_html(web_url)[0]#.dropna()
# Out:
#       Date Unnamed: 1_level_0  \
#       Date Unnamed: 1_level_1
# 0    1 Jan           Saturday
# 1   23 Jan             Sunday
# 2      NaN                NaN
# 3    1 Feb            Tuesday
# 4   25 Feb             Friday
# 5      NaN                NaN
# 6    1 Mar            Tuesday
# 7   20 Mar             Sunday
# 8      NaN                NaN
# 9    9 Apr           Saturday
# 10  14 Apr           Thursday
# 11  15 Apr             Friday
# 12  16 Apr           Saturday
# 13  17 Apr             Sunday
# 14     NaN                NaN
# 15   1 May             Sunday
# 16   3 May            Tuesday
# 17     NaN                NaN
# 18  12 Jun             Sunday
# 19  21 Jun            Tuesday
# 20     NaN                NaN
# 21  10 Jul             Sunday
# 22  11 Jul             Monday
# 23  30 Jul           Saturday
# 24     NaN                NaN
# 25  21 Aug             Sunday
# 26  29 Aug             Monday
# 27     NaN                NaN
# 28   3 Sep           Saturday
# 29   8 Sep           Thursday
# 30  23 Sep             Friday
# 31     NaN                NaN
# 32   8 Oct           Saturday
# 33     NaN                NaN
# 34   1 Nov            Tuesday
# 35   2 Nov          Wednesday
# 36  30 Nov          Wednesday
# 37     NaN                NaN
# 38   8 Dec           Thursday
# 39  22 Dec           Thursday
# 40  24 Dec           Saturday
# 41  25 Dec             Sunday
# 42  30 Dec             Friday
# 43  31 Dec           Saturday
#
#                                                  Name  \
#                                                  Name
# 0                                      New Year's Day
# 1                       First Philippine Republic Day
# 2                                                 NaN
# 3                        Chinese Lunar New Year's Day
# 4                            People Power Anniversary
# 5                                                 NaN
# 6                            Lailatul Isra Wal Mi Raj
# 7                                       March Equinox
# 8                                                 NaN
# 9                                    The Day of Valor
# 10                                    Maundy Thursday
# 11                                        Good Friday
# 12                                     Black Saturday
# 13                                      Easter Sunday
# 14                                                NaN
# 15                                          Labor Day
# 16                                        Eidul-Fitar
# 17                                                NaN
# 18                                   Independence Day
# 19                                      June Solstice
# 20                                                NaN
# 21  Eid al-Adha (Feast of the Sacrifice) (Tentativ...
# 22                 Eid al-Adha Day 2 (Tentative Date)
# 23                                         Amun Jadid
# 24                                                NaN
# 25                                   Ninoy Aquino Day
# 26                                National Heroes Day
# 27                                                NaN
# 28                            Yamashita Surrender Day
# 29                      Feast of the Nativity of Mary
# 30                                  September Equinox
# 31                                                NaN
# 32                                     Maulid un-Nabi
# 33                                                NaN
# 34                                    All Saints' Day
# 35                                     All Souls' Day
# 36                                      Bonifacio Day
# 37                                                NaN
# 38                 Feast of the Immaculate Conception
# 39                                  December Solstice
# 40                                      Christmas Eve
# 41                                      Christmas Day
# 42                                          Rizal Day
# 43                                     New Year's Eve
#
#                               Type Details
#                               Type Details
# 0                  Regular Holiday     NaN
# 1   Special Working Public Holiday     NaN
# 2                              NaN     NaN
# 3      Special Non-working Holiday     NaN
# 4      Special Non-working Holiday     NaN
# 5                              NaN     NaN
# 6             Common local holiday     NaN
# 7                           Season     NaN
# 8                              NaN     NaN
# 9                  Regular Holiday     NaN
# 10                 Regular Holiday     NaN
# 11                 Regular Holiday     NaN
# 12     Special Non-working Holiday     NaN
# 13                      Observance     NaN
# 14                             NaN     NaN
# 15                 Regular Holiday     NaN
# 16                 Regular Holiday     NaN
# 17                             NaN     NaN
# 18                 Regular Holiday     NaN
# 19                          Season     NaN
# 20                             NaN     NaN
# 21                 Regular Holiday     NaN
# 22            Common local holiday     NaN
# 23    Muslim, Common local holiday     NaN
# 24                             NaN     NaN
# 25     Special Non-working Holiday     NaN
# 26                 Regular Holiday     NaN
# 27                             NaN     NaN
# 28  Special Working Public Holiday     NaN
# 29  Special Working Public Holiday     NaN
# 30                          Season     NaN
# 31                             NaN     NaN
# 32            Common local holiday     NaN
# 33                             NaN     NaN
# 34     Special Non-working Holiday     NaN
# 35                      Observance     NaN
# 36                 Regular Holiday     NaN
# 37                             NaN     NaN
# 38     Special Non-working Holiday     NaN
# 39                          Season     NaN
# 40                      Observance     NaN
# 41                 Regular Holiday     NaN
# 42                 Regular Holiday     NaN
# 43     Special Non-working Holiday     NaN

# %%
countries_urls.index(country_url)
# Out:
# 0

# %%
df = pd.concat(all_dfs)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Date, Day, Name, Type, Details, Country, Year]
# Index: []

# %%
# df.reset_index().drop(['index'], axis=1).to_excel('Holidays Data.xlsx', index=False)

# %%
df['Date'] = df['Date_'] + " " + df['Year']

# %%
df.Date =  df.Date.apply(lambda x: datetime.strptime(x, '%d %b %Y'))

# %%
df.to_excel('temp.xlsx', index=False)

# %%
import requests
import os
import pandas as pd
from bs4 import BeautifulSoup
import json
from time import sleep
from tqdm.auto import tqdm

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36 Edg/89.0.774.63',}
site = requests.get('https://www.timeanddate.com/holidays/?allcountries', headers=headers,)
soup = BeautifulSoup(site.content)

# urls of all the countries
countries_urls = ["https://www.timeanddate.com"+x.find('a')['href'] for x in soup.find("article", {'class':'category-list'}).findAll('li')]

# the years we want to extract. you can change this and use the years you want.
years = ["2018","2019", "2020", "2021", "2022"]

all_dfs = []
for country_url in tqdm(countries_urls): # country loop
    print(country_url, end=" => ") 
    for year in years: # year loop
        
        web_url = country_url + year
        try:
            df = pd.read_html(web_url)[0].dropna()
        except ValueError: # in case there is not tables in the website
            continue
        if len(df.columns) == 4:
            df['Details'] = ""
        df.columns = ["Date", "Day", "Name", "Type" , "Details"]
        df['Country'] = country_url.split("/")[-2].capitalize()
        df['Year'] = year
        all_dfs.append(df)
        
        print(df.shape[0], end=", ")
        del df 
    print()
        
#         break
#     break


df = pd.concat(all_dfs)
df.reset_index().drop(['index'], axis=1).to_excel('Holidays Data.xlsx', index=False)
