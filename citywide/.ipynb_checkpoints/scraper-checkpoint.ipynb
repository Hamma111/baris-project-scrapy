# %%
import requests
import os
import pandas as pd
from bs4 import BeautifulSoup
import http.cookies
import re
import json
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from time import sleep
from multiprocessing.dummy import Pool as ThreadPool

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36 Edg/89.0.774.63',
          }

# %%
prod_urls = []
for page_num in range(1, 3):
    url = f'https://www.citiwide-online.com/categories/orient-classic-series?limit=72&page={page_num}'
    site = requests.get(url)
    soup = BeautifulSoup(site.content, 'lxml')
    prod_urls += ["https://www.citiwide-online.com"+x.find('a')['href'] for x in soup.findAll('product-item')]

# %%
name_array, original_price_array, discount_price_array = [], [], []
img_urls_array, description_html_array, description_text_array = [], [], []
prod_urls_array = []

# %%
def scrapify(url):
    site = requests.get(url, headers=headers)
    soup = BeautifulSoup(site.content)
    title = soup.find('div', {'class':'title global-primary dark-primary'}).getText('', True)
    orignal_price = soup.find('div', {'class':'global-primary dark-primary price-regular price js-price price-crossed'}).getText('', True)
    discount_price = soup.find('div', {'class':'price-sale price js-price'}).getText('', True)
    description_text = soup.find('div', {'class':'global-secondary dark-secondary description-container'}).getText('', True)
    description_html = soup.find('div', {'class':'global-secondary dark-secondary description-container'})
    img_urls = []
    for temp in str(soup).split('detail_image_url')[1:]:
        img_urls.append(temp.split('?\\')[0][5:])
        
    
    name_array.append(title)
    original_price_array.append(orignal_price)
    discount_price_array.append(discount_price)
    description_text_array.append(description_text)
    description_html_array.append(description_html)
    img_urls_array.append(img_urls)
    prod_urls_array.append(url)

# %%
# for product_url in prod_urls[:5]:
#     scrapify(product_url, url)

# %%
pool = ThreadPool(20)
_ = pool.map(scrapify, prod_urls[:])

# %%
del df

# %%
df = pd.DataFrame(columns=['Handle', 'Title', 'Description(HTML)', 'Description(text)','OriginalPrice',
                           'DiscountedPrice', 'ProductURL', 'Image Src', 'Image Position'
                            ])

# %%
for index, imgs in enumerate(img_urls_array):
    for i, src in enumerate(imgs):
        if i== 0:
            df = df.append({
                'Handle': name_array[index],
                'Title': name_array[index],
                'Description(HTML)': description_html_array[index],
                'Description(text)': description_text_array[index],
                'OriginalPrice': original_price_array[index],
                'DiscountedPrice': discount_price_array[index],
                'ProductURL': prod_urls_array[index],
                'Image Src': src,
                'Image Position': i+1
            }, ignore_index = True)
        else:
            df = df.append({
                'Handle': name_array[index],
                'Title': '',
                'Description(HTML)': '',
                'Description(text)': '',
                'OriginalPrice':  '',
                'DiscountedPrice' ''
                'ProductURL': '',
                'Image Src': src,
                'Image Position': i+1
            }, ignore_index = True)

# %%
df.head(10)
# Out:
#                                    Description(HTML)  \
# 0  <div class="global-secondary dark-secondary de...
# 1
# 2  <div class="global-secondary dark-secondary de...
# 3
# 4
# 5  <div class="global-secondary dark-secondary de...
# 6
# 7
# 8  <div class="global-secondary dark-secondary de...
# 9
#
#                                    Description(text) DiscountedPrice  \
# 0  不銹鋼錶殼不銹鋼手鍊自動機芯礦物水晶模擬顯示黑色錶盤日期和日期顯示擰回螺絲冠熒光箭頭和標籤1...     HK$1,150.00
# 1                                                                NaN
# 2  產品規格品牌：東方系列：星型號：RK-DE0301L機芯：機械自動機芯編號：40A52驅動系...     HK$5,880.00
# 3                                                                NaN
# 4                                                                NaN
# 5  產品規格品牌：東方系列：東方之星性別：男士機芯：自動口徑：F6N47錶殼材料：不銹鋼錶殼形狀...     HK$3,950.00
# 6                                                                NaN
# 7                                                                NaN
# 8  產品規格機芯：F6722機芯自動上鍊黑客運動動力儲備：約40小時特點：日期，發光標記晶體：藍...     HK$2,430.00
# 9                                                                NaN
#
#                                            Handle  Image Position  \
# 0          ORIENT 東方萬年曆機械手錶 SEU07005BX/FEU07005BX             1.0
# 1          ORIENT 東方萬年曆機械手錶 SEU07005BX/FEU07005BX             2.0
# 2    ORIENT東方之星 RETROGRADE系列 經典星期逆跳機械錶 RK-DE0301L             1.0
# 3    ORIENT東方之星 RETROGRADE系列 經典星期逆跳機械錶 RK-DE0301L             2.0
# 4    ORIENT東方之星 RETROGRADE系列 經典星期逆跳機械錶 RK-DE0301L             3.0
# 5  東方之星 - Orient Star 潛水系列 200m 防水男士手錶 RK-AU0303B             1.0
# 6  東方之星 - Orient Star 潛水系列 200m 防水男士手錶 RK-AU0303B             2.0
# 7  東方之星 - Orient Star 潛水系列 200m 防水男士手錶 RK-AU0303B             3.0
# 8           Orient 東方200米潛水系列自動機械手錶 RA-AC0K05G00C             1.0
# 9           Orient 東方200米潛水系列自動機械手錶 RA-AC0K05G00C             2.0
#
#                                            Image Src OriginalPrice  \
# 0  https://shoplineimg.com/5d02035403a5360001dbbe...   HK$2,550.00
# 1  https://shoplineimg.com/5d02035403a5360001dbbe...
# 2  https://shoplineimg.com/5d02035403a5360001dbbe...   HK$7,840.00
# 3  https://shoplineimg.com/5d02035403a5360001dbbe...
# 4  https://shoplineimg.com/5d02035403a5360001dbbe...
# 5  https://shoplineimg.com/5d02035403a5360001dbbe...   HK$6,095.00
# 6  https://shoplineimg.com/5d02035403a5360001dbbe...
# 7  https://shoplineimg.com/5d02035403a5360001dbbe...
# 8  https://shoplineimg.com/5d02035403a5360001dbbe...   HK$3,750.00
# 9  https://shoplineimg.com/5d02035403a5360001dbbe...
#
#                                           ProductURL  \
# 0  https://www.citiwide-online.com/products/5ec39...
# 1                                                NaN
# 2  https://www.citiwide-online.com/products/5feac...
# 3                                                NaN
# 4                                                NaN
# 5  https://www.citiwide-online.com/products/605c0...
# 6                                                NaN
# 7                                                NaN
# 8  https://www.citiwide-online.com/products/601b7...
# 9                                                NaN
#
#                                             Title DiscountedPriceProductURL
# 0          ORIENT 東方萬年曆機械手錶 SEU07005BX/FEU07005BX                       NaN
# 1
# 2    ORIENT東方之星 RETROGRADE系列 經典星期逆跳機械錶 RK-DE0301L                       NaN
# 3
# 4
# 5  東方之星 - Orient Star 潛水系列 200m 防水男士手錶 RK-AU0303B                       NaN
# 6
# 7
# 8           Orient 東方200米潛水系列自動機械手錶 RA-AC0K05G00C                       NaN
# 9

# %%
df.columns
# Out:
# Index(['Handle', 'Title', 'Description(HTML)', 'Description(text)',
#        'OriginalPrice', 'DiscountedPrice', 'ProductURL', 'Image Src',
#        'Image Position', 'DiscountedPriceProductURL'],
#       dtype='object')

# %%
df.drop(['DiscountedPriceProductURL'], axis=1, inplace=True)

# %%
df.to_csv('citywide - orient.csv', index=False)

# %%
df.to_excel('citywide - orient.xlsx', index=False)
